# %%
# !ls -l
# Out:
# total 1592
# -rw-r--r--   1 sampathm  staff  771152 Feb 26 13:41 Untitled.ipynb
# -rw-r--r--   1 sampathm  staff      95 Feb 26 12:22 __init__.py
# drwxr-xr-x  10 sampathm  staff     320 Feb 26 12:22 __pycache__
# -rw-r--r--   1 sampathm  staff    3336 Feb 26 12:22 annotate.py
# drwxr-xr-x   3 sampathm  staff      96 Feb 26 12:17 bin
# -rw-r--r--   1 sampathm  staff     839 Feb 26 12:22 config.py
# -rw-r--r--   1 sampathm  staff    1665 Feb 26 12:22 cropper.py
# -rw-r--r--   1 sampathm  staff     990 Feb 26 12:22 development_plan.md
# -rw-r--r--@  1 sampathm  staff     667 Feb 26 12:41 lp.jpg
# drwxr-xr-x   9 sampathm  staff     288 Feb 26 12:17 notebooks
# -rw-r--r--   1 sampathm  staff       5 Feb  8 11:11 requirements.txt
# -rw-r--r--   1 sampathm  staff    2492 Feb 26 12:22 run.py
# drwxr-xr-x  13 sampathm  staff     416 Feb 26 12:22 static
# drwxr-xr-x  14 sampathm  staff     448 Feb 26 12:22 templates
# -rw-r--r--   1 sampathm  staff    5655 Feb 26 12:22 views.py

# %%
import image_manager
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-52-791c4a142ee8> in <module>
# ----> 1 import image_manager
#
# ModuleNotFoundError: No module named 'image_manager'

# %%
image_manager.GetNewImage.refresh()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-302a452d6ba3> in <module>
# ----> 1 image_manager.GetNewImage.refresh()
#
# NameError: name 'image_manager' is not defined

# %%
preference_list = [
    'binerisation_url',
    'cropper_url',
    'url'
]

def get_image_url(image_dict, preference_list=preference_list):
    for key in preference_list:
        url = image_dict.get(key)
        if url:
            return url
    raise Exception('No Preference List\'s URL is in {}'.format(str(image_dict)))
    

receipt_images = image_manager.GetNewImage.receipt_images

all_receipt_images = list(receipt_images.keys())[:12]

for image_id in all_receipt_images:
    print(get_image_url(receipt_images[image_id]))
    image_path = os.path.join(config.ROOT_DIR, receipt_images[image_id]['url'])
    binerisation_path = os.path.join(config.ROOT_DIR, config.BINERIZE_ROOT_DIR, receipt_images[image_id]['file'])
    print('processing,...{}'.format())
# Out:
# static/data/cropper/711_crayola_receipt_zoomed.jpg
# static/data/images/265medium.jpg
# static/data/images/1d274906515745todaypizzahut14080601blocks_desktop_small.jpg
# static/data/cropper/011.jpg
# static/data/images/7c0acecb82f80849b9d4189c5fe94a09.jpg
# static/data/cropper/006.jpg
# static/data/cropper/6a00d8341c5da453ef014e883a4fd0970d320wi.jpg
# static/data/images/348s_14.jpg
# static/data/images/348s_15.jpg
# static/data/cropper/011224x300.jpg
# static/data/cropper/2jfm8sj.jpg
# static/data/images/200pxreceiptswiss.jpg

# %%
import config

import os

# %%
image_url = receipt_images[image_id]['url']

image_url
# Out:
# 'static/data/images/200pxreceiptswiss.jpg'

# %%
config.ROOT_DIR
# Out:
# '/Users/sampathm/devbox/vitaFlow/vitaflow/annotate_server'

# %%
image_path = os.path.join(config.ROOT_DIR, receipt_images[image_id]['url'])

binerisation_path = os.path.join(config.ROOT_DIR, config.BINERIZE_ROOT_DIR, receipt_images[image_id]['file'])

# %%
image_path = '/Users/sampathm/devbox/vitaFlow/vitaflow/annotate_server/static/data/images/265medium.jpg'

# %%
binerisation_path = '/Users/sampathm/devbox/vitaFlow/vitaflow/annotate_server/static/data/binerisation/265medium.jpg'

# %%
# %%time

binarisation.binarisation(image_path, binerisation_path)
# Out:
# CPU times: user 2.53 ms, sys: 7.92 ms, total: 10.5 ms
# Wall time: 1.3 s

# %% [markdown]
# ## asynio

# %%
import asyncio
import datetime

async def display_date(loop):
    end_time = loop.time() + 5.0
    while True:
        print(datetime.datetime.now())
        if (loop.time() + 1.0) >= end_time:
            break
        await asyncio.sleep(1)

loop = asyncio.get_event_loop()
# Blocking call which returns when the display_date() coroutine is done
loop.run_until_complete(display_date(loop))
loop.close()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-24-2c4a22a06668> in <module>
#      12 loop = asyncio.get_event_loop()
#      13 # Blocking call which returns when the display_date() coroutine is done
# ---> 14 loop.run_until_complete(display_date(loop))
#      15 loop.close()
#
# ~/anaconda3/lib/python3.6/asyncio/base_events.py in run_until_complete(self, future)
#     469         future.add_done_callback(_run_until_complete_cb)
#     470         try:
# --> 471             self.run_forever()
#     472         except:
#     473             if new_task and future.done() and not future.cancelled():
#
# ~/anaconda3/lib/python3.6/asyncio/base_events.py in run_forever(self)
#     423         self._check_closed()
#     424         if self.is_running():
# --> 425             raise RuntimeError('This event loop is already running')
#     426         if events._get_running_loop() is not None:
#     427             raise RuntimeError(
#
# RuntimeError: This event loop is already running
# 2019-02-26 11:14:25.549363
# 2019-02-26 11:14:26.553692
# 2019-02-26 11:14:27.558730
# 2019-02-26 11:14:28.561016
# 2019-02-26 11:14:29.566643

# %% [markdown]
# ## play time -11:18

# %%
# !ls /Users/sampathm/Downloads/00P8RO5779B44468DA391Cl*
# Out:
# /Users/sampathm/Downloads/00P8RO5779B44468DA391Cl.jpg
# /Users/sampathm/Downloads/00P8RO5779B44468DA391Cl.jpg_act.jpg
# /Users/sampathm/Downloads/00P8RO5779B44468DA391Cl.jpg_predict.jpg
# /Users/sampathm/Downloads/00P8RO5779B44468DA391Cl.txt

# %%
input_file = '/Users/sampathm/Downloads/00P8RO5779B44468DA391Cl.txt'

# %%
input_file = '/Users/sampathm/Downloads/00P8RO5779B44468DA391Cl.txt'
data = open(input_file).read().splitlines()

# %%
bag = []
for line in data:
    x1, y1, x2, y2, x3, y3, x4, y4 = list(map(round, map(float, line.split(','))))
    _x = [x1, x2, x3, x4]
    _y = [y1, y2, y3, y4]
    x_max = max(_x)
    x_min = min(_x)
    y_max = max(_y)
    y_min = min(_y)
    coords = [y_min, y_max, x_min, x_max]
    bag.append(coords)

# %%
x1, y1, x2, y2, x3, y3, x4, y4
# Out:
# (211, 326, 211, 340, 269, 337, 269, 325)

# %%
_x, x_min, x_max
# Out:
# ([211, 211, 269, 269], 211, 269)

# %%
coords = [y_min, y_max, x_min, x_max]

# %%
plt.imshow(img[y_min:y_max, x_min:x_max])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-d9cbe0b0f7af> in <module>
# ----> 1 plt.imshow(img[y_min:y_max, x_min:x_max])
#
# NameError: name 'img' is not defined

# %%
bag
# Out:
# [[26, 37, 191, 250],
#  [40, 49, 167, 265],
#  [59, 71, 192, 257],
#  [84, 100, 218, 249],
#  [110, 124, 206, 293],
#  [137, 151, 182, 253],
#  [141, 151, 117, 163],
#  [154, 164, 117, 161],
#  [152, 164, 183, 225],
#  [158, 176, 183, 295],
#  [166, 177, 116, 142],
#  [181, 193, 324, 350],
#  [185, 204, 182, 286],
#  [206, 216, 184, 218],
#  [222, 235, 331, 358],
#  [236, 249, 114, 165],
#  [254, 267, 317, 369],
#  [267, 280, 115, 146],
#  [270, 281, 314, 365],
#  [283, 297, 340, 368],
#  [300, 313, 113, 141],
#  [325, 340, 211, 269]]

# %%
img = plt.imread('/Users/sampathm/Downloads/00P8RO5779B44468DA391Cl.jpg')

# %%
plt.figure(figsize=(20, 20))
plt.imshow(img[26:340, 113:369])
plt.imsave('/Users/sampathm/Desktop/download.jpg', img[26:340, 113:369])

# %% [raw]
# coords = bag[5]
# x1, x2, y1, y2 = coords
# plt.imshow(img[x1:x2, y1:y2])

# %% [markdown]
# # hello

# %%
import numpy as np
import cv2
import imutils, traceback
import sys
import matplotlib.pyplot as plt


def four_point_transform(image, pts):
    # obtain a consistent order of the points and unpack them
    # individually
    rect = order_points(pts)
    (tl, tr, br, bl) = rect
 
    # compute the width of the new image, which will be the
    # maximum distance between bottom-right and bottom-left
    # x-coordiates or the top-right and top-left x-coordinates
    widthA = np.sqrt(((br[0] - bl[0]) ** 2) + ((br[1] - bl[1]) ** 2))
    widthB = np.sqrt(((tr[0] - tl[0]) ** 2) + ((tr[1] - tl[1]) ** 2))
    maxWidth = max(int(widthA), int(widthB))
 
    # compute the height of the new image, which will be the
    # maximum distance between the top-right and bottom-right
    # y-coordinates or the top-left and bottom-left y-coordinates
    heightA = np.sqrt(((tr[0] - br[0]) ** 2) + ((tr[1] - br[1]) ** 2))
    heightB = np.sqrt(((tl[0] - bl[0]) ** 2) + ((tl[1] - bl[1]) ** 2))
    maxHeight = max(int(heightA), int(heightB))
 
    # now that we have the dimensions of the new image, construct
    # the set of destination points to obtain a "birds eye view",
    # (i.e. top-down view) of the image, again specifying points
    # in the top-left, top-right, bottom-right, and bottom-left
    # order
    dst = np.array([
        [0, 0],
        [maxWidth - 1, 0],
        [maxWidth - 1, maxHeight - 1],
        [0, maxHeight - 1]], dtype = "float32")
 
    # compute the perspective transform matrix and then apply it
    M = cv2.getPerspectiveTransform(rect, dst)
    warped = cv2.warpPerspective(image, M, (maxWidth, maxHeight))
 
    # return the warped image
    return warped


def order_points(pts):
    # initialzie a list of coordinates that will be ordered
    # such that the first entry in the list is the top-left,
    # the second entry is the top-right, the third is the
    # bottom-right, and the fourth is the bottom-left
    rect = np.zeros((4, 2), dtype = "float32")
 
    # the top-left point will have the smallest sum, whereas
    # the bottom-right point will have the largest sum
    s = pts.sum(axis = 1)
    rect[0] = pts[np.argmin(s)]
    rect[2] = pts[np.argmax(s)]
 
    # now, compute the difference between the points, the
    # top-right point will have the smallest difference,
    # whereas the bottom-left will have the largest difference
    diff = np.diff(pts, axis = 1)
    rect[1] = pts[np.argmin(diff)]
    rect[3] = pts[np.argmax(diff)]
 
    # return the ordered coordinates
    return rect


# Read the image file
print(sys.argv[1])
# image = cv2.imread('/Users/sampathm/Downloads/00P8RO5779B44468DA391Cl.jpg')
image = cv2.imread('/Users/sampathm/Desktop/download.jpg')

# Resize the image - change width to 500
# image = imutils.resize(image, width=250)

# Display the original image
plt.figure(figsize=(20,20))
plt.imshow(image)
# Out:
# -f

# %%
# RGB to Gray scale conversion
gray = cv2.cvtColor(image, 0)
#cv2.imshow("1 - Grayscale Conversion", gray)

# Noise removal with iterative bilateral filter(removes noise while preserving edges)
# gray = cv2.bilateralFilter(gray, 11, 17, 17)
plt.figure(figsize=(20,20))
plt.imshow(gray, 'gray')
cv2.imwrite("gray.jpg", gray)
# Out:
# True

# %%
# Out:
# 8210

# %%
gray = plt.imread('gray.jpg')
thresh  = 165
# gray = cv2.threshold(gray, thresh, 255, cv2.THRESH_BINARY)[1]
#cv2.imshow()
#sys.exit(0)
# Find Edges of the grayscale image
edged = cv2.Canny(gray, 50, 200)
lines = cv2.HoughLines(edged,1,np.pi/180,10)
plt.figure(figsize=(20,20))
plt.imshow(edged, 'gray')

# %%
for rho,theta in lines[0]:
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a*rho
    y0 = b*rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))

    cv2.line(gray,(x1,y1),(x2,y2),(0,0,255),2)

# %%
plt.imshow(gray)

# %%
#print(lines)

cv2.imwrite('houghlines3.jpg',image)
"""

"""
plt.figure(figsize=(20,20))
plt.imshow(edged, 'gray')
cv2.imwrite("temp/edge.jpg", edged)
# Out:
# [[[  0 255 255 255]
#   [  0 255 255 255]
#   [  0 255 255 255]
#   ...
#   [  0   0   0 255]
#   [  0   0   0 255]
#   [  0   0   0 255]]
#
#  [[  0 255 255 255]
#   [  0 255 255 255]
#   [  0 255 255 255]
#   ...
#   [  0   0   0 255]
#   [  0   0   0 255]
#   [  0   0   0 255]]
#
#  [[  0 255 255 255]
#   [  0 255 255 255]
#   [255 255 255 255]
#   ...
#   [  0   0   0 255]
#   [  0   0   0 255]
#   [  0   0   0 255]]
#
#  ...
#
#  [[  0 255 255 255]
#   [  0 255 255 255]
#   [  0 255 255 255]
#   ...
#   [  0 255 255 255]
#   [  0 255 255 255]
#   [  0 255 255 255]]
#
#  [[  0 255 255 255]
#   [  0 255 255 255]
#   [  0 255 255 255]
#   ...
#   [  0 255 255 255]
#   [  0 255 255 255]
#   [  0 255 255 255]]
#
#  [[  0 255 255 255]
#   [  0 255 255 255]
#   [  0 255 255 255]
#   ...
#   [  0 255 255 255]
#   [  0 255 255 255]
#   [  0 255 255 255]]]
# False

# %%
thresh  = 165
gray = cv2.threshold(gray, thresh, 255, cv2.THRESH_BINARY)[1]
print(gray)
#cv2.imshow()
cv2.imwrite('temp/gaurish.jpg', gray)
#sys.exit(0)
# Find Edges of the grayscale image
edged = cv2.Canny(gray, 100, 200)
#lines = cv2.HoughLinesP(edged,1,np.pi/30,10, 50, 5)
#print(lines)
"""
for rho,theta in lines[0]:
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a*rho
    y0 = b*rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))

    cv2.line(image,(x1,y1),(x2,y2),(0,0,255),2)

cv2.imwrite('temp/houghlines3.jpg',image)
"""
plt.figure(figsize=(20,20))
plt.imshow(edged)
cv2.imwrite("temp/edge.jpg", edged)
# Find contours based on Edges
(new, cnts, _) = cv2.findContours(edged.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
cnts=sorted(cnts, key = cv2.contourArea, reverse = True)[:30] #sort contours based on their area keeping minimum required area as '30' (anything smaller than this will not be considered)

NumberPlateCnt = None #we currently have no Number plate contour
# Out:
# [[[  0 255 255 255]
#   [  0 255 255 255]
#   [  0 255 255 255]
#   ...
#   [  0   0   0 255]
#   [  0   0   0 255]
#   [  0   0   0 255]]
#
#  [[  0 255 255 255]
#   [  0 255 255 255]
#   [  0 255 255 255]
#   ...
#   [  0   0   0 255]
#   [  0   0   0 255]
#   [  0   0   0 255]]
#
#  [[  0 255 255 255]
#   [  0 255 255 255]
#   [255 255 255 255]
#   ...
#   [  0   0   0 255]
#   [  0   0   0 255]
#   [  0   0   0 255]]
#
#  ...
#
#  [[  0 255 255 255]
#   [  0 255 255 255]
#   [  0 255 255 255]
#   ...
#   [  0 255 255 255]
#   [  0 255 255 255]
#   [  0 255 255 255]]
#
#  [[  0 255 255 255]
#   [  0 255 255 255]
#   [  0 255 255 255]
#   ...
#   [  0 255 255 255]
#   [  0 255 255 255]
#   [  0 255 255 255]]
#
#  [[  0 255 255 255]
#   [  0 255 255 255]
#   [  0 255 255 255]
#   ...
#   [  0 255 255 255]
#   [  0 255 255 255]
#   [  0 255 255 255]]]

# %%
for c in cnts:

    peri = cv2.arcLength(c, True)
    approx = cv2.approxPolyDP(c, 0.02 * peri, True)
    if len(approx) == 4: 
        break

# %%
approx
# Out:
# array([[[150,  33]],
#
#        [[149,  34]],
#
#        [[149,  39]],
#
#        [[151,  39]],
#
#        [[151,  34]]], dtype=int32)

# %%
# loop over our contours to find the best possible approximate contour of number plate
count = 0

for c in cnts:

    peri = cv2.arcLength(c, True)
    approx = cv2.approxPolyDP(c, 0.02 * peri, True)
    if len(approx) >= 4 and len(approx) <= 10:  # Select the contour with 4 corners
    #if len(approx) == 4:
        count += 1
        NumberPlateCnt = approx #This is our approx Number Plate Contour
        print(len(approx))
        break
        """
        pts = NumberPlateCnt.reshape((4,2)).astype('float32')
        print(pts)
        warped = four_point_transform(image, pts)
        cv2.imwrite('temp/lp' + str(count) +'.jpg', warped)
        #break
print('ok')
        """

pts = NumberPlateCnt.reshape((len(approx),2)).astype('float32')
print(pts)
# Drawing the selected contour on the original image
#x = cv2.drawContours(image, [NumberPlateCnt], -1, (0,255,0), 3)
#cv2.imwrite("temp.jpg", x)
plt.imshow(image)

try:
    warped = four_point_transform(image, pts)
except:
    traceback.print_exc()

cv2.imwrite('lp.jpg', warped)
